# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('..')

# %%
import numpy as np

from magnet_pinn.preprocessing.preprocessing import GridPreprocessing, GraphPreprocessing

# %%
preprocessor = GridPreprocessing(
    "../data/raw/batch_1",
    "../data/processed/batch_1",
    field_dtype=np.complex64,
    x_min=-240,
    x_max=240,
    y_min=-220,
    y_max=220,
    z_min=-250,
    z_max=250
)

# %%
preprocessor.process_simulations(
    ["children_0_tubes_0_id_18840", "children_1_tubes_1_id_24879"]
)
# Out:
# 100%|██████████| 2/2 [00:17<00:00,  8.78s/it, done=children_1_tubes_1_id_24879]

# %%
graph_preprocessor = GraphPreprocessing(
    "../data/raw/batch_1",
    "../data/processed/batch_1",
    field_dtype=np.complex64
)

# %%
graph_preprocessor.process_simulations(
    ["children_0_tubes_0_id_18840", "children_1_tubes_1_id_24879"]
)
# Out:
# ...
# 100%|██████████| 2/2 [00:06<00:00,  3.19s/it, done=children_1_tubes_1_id_24879]
