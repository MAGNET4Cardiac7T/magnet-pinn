# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('..')

# %%
import numpy as np

from magnet_pinn.preprocessing.preprocessing import GridPreprocessing, PointPreprocessing

# %%
preprocessor = GridPreprocessing(
    "../data/raw/batch_6",
    "../data/processed/batch_6",
    field_dtype=np.float16,
    x_min=-240,
    x_max=240,
    y_min=-220,
    y_max=220,
    z_min=-250,
    z_max=250
)

# %%
preprocessor.process_simulations(simulation_names=["children_1_tubes_1_id_28563"])

# %%
point_preprocessor = PointPreprocessing(
    "../data/raw/batch_6",
    "../data/processed/batch_6",
    field_dtype=np.complex64
)

# %%
point_preprocessor.process_simulations()
